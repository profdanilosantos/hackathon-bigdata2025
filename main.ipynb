# %% [markdown]
# # 1. Importar bibliotecas

# %%
import duckdb
import pandas as pd
import numpy as np

# %% [markdown]
# ### Conecta no DuckDB

# %%
# Conecta abrindo / criando um arquivo
conn = duckdb.connect('./dados/hackathon_2025.duckdb')

# %% [markdown]
# # 2. Carregar os dados

# %%
# Gravação no formato Parquet
df_pdv = conn.execute("""
    SELECT
    *
    FROM
    read_parquet('./dados/hackathon_2025_templates/part-00000-tid-2779033056155408584-f6316110-4c9a-4061-ae48-69b77c7c8c36-4-1-c000.snappy.parquet')
""").fetchdf()
df_pdv.head()
# Out:
#                    pdv      premise categoria_pdv  zipcode
# 0  2204965430669363375   On Premise  Mexican Rest    30741
# 1  5211957289528622910   On Premise   Hotel/Motel    80011
# 2  9024493554530757353  Off Premise   Convenience    80751
# 3  8659197371382902429   On Premise    Restaurant    80439
# 4  1400854873763881130   On Premise    Restaurant    30093

# %%
# Gravação no formato Parquet
df_transacao = conn.execute("""
    SELECT
    *
    FROM
    read_parquet('./dados/hackathon_2025_templates/part-00000-tid-5196563791502273604-c90d3a24-52f2-4955-b4ec-fb143aae74d8-4-1-c000.snappy.parquet')
""").fetchdf()
df_transacao.head()
# Out:
#      internal_store_id  internal_product_id distributor_id transaction_date  \
# 0  2204965430669363375  8654618855511723434              4       2022-05-10
# 1  2204965430669363375  5168467358507505407              4       2022-08-01
# 2  2204965430669363375  3262679882836704514              4       2022-08-01
# 3  2204965430669363375    14523659809755688              4       2022-07-08
# 4  2204965430669363375  2888002190098573554              4       2022-10-24
#
#   reference_date  quantity  gross_value  net_value  gross_profit  discount  \
# 0     2022-05-01       1.0    19.990000  19.990000      5.990000       1.0
# 1     2022-08-01      12.0    52.799999  38.158596      7.188600       7.2
# 2     2022-08-01       2.0    47.200001  42.640484     12.474483       0.0
# 3     2022-07-01       1.0    23.500000  22.584913      5.498246       2.8
# 4     2022-10-01       1.0    25.000000  25.000000      7.500000       0.0
#
#        taxes
# 0   0.000000
# 1  14.641404
# 2   4.559516
# ...

# %%
df_transacao.describe()
# Out:
#                  transaction_date              reference_date   quantity  \
# count                          97                          97  97.000000
# mean   2022-07-06 16:19:47.628866  2022-06-21 00:14:50.721649   7.381443
# min           2022-01-07 00:00:00         2022-01-01 00:00:00   1.000000
# 25%           2022-04-14 00:00:00         2022-04-01 00:00:00   1.000000
# 50%           2022-06-27 00:00:00         2022-06-01 00:00:00   2.000000
# 75%           2022-10-03 00:00:00         2022-10-01 00:00:00   7.000000
# max           2022-12-22 00:00:00         2022-12-01 00:00:00  48.000000
# std                           NaN                         NaN  11.319639
#
#        gross_value   net_value  gross_profit    discount      taxes
# count    97.000000   97.000000     97.000000   97.000000  97.000000
# mean    193.548969  174.413976     65.700815   19.678763  19.134994
# min      12.300000   12.300000      3.800000    0.000000   0.000000
# ...

# %%
# Gravação no formato Parquet
df_produto = conn.execute("""
    SELECT
    *
    FROM
    read_parquet('./dados/hackathon_2025_templates/part-00000-tid-7173294866425216458-eae53fbf-d19e-4130-ba74-78f96b9675f1-4-1-c000.snappy.parquet')
    LIMIT 1000
""").fetchdf()
df_produto.head()
# Out:
#                produto          categoria  \
# 0  2282334733936076502  Distilled Spirits
# 1  6091840953834683482  Distilled Spirits
# 2  1968645851245092408  Distilled Spirits
# 3   994706710729219179              Draft
# 4  9209550539540384349        Non-Alcohol
#
#                               descricao              tipos          label  \
# 0           JOSEPH CARTRON CAFÉ LIQUEUR  Distilled Spirits           Core
# 1  SPRINGBANK 18 YEAR SINGLE MALT 700ML  Distilled Spirits      Specialty
# 2     J BRANDT TRIPLE SEC 12/750ML 30PF  Distilled Spirits  Private Label
# 3      REFORMATION CASHMERE IPA 1/4 KEG              Draft         In&Out
# 4               HELLA MOSCOW MULE 750ML        Non Alcohol           Core
#
#           subcategoria                               marca  \
# 0  Liqueurs & Cordials                 Joseph Cartron Cafe
# 1        Scotch Whisky      Springbank 18 Year Single Malt
# 2  Liqueurs & Cordials                 J Brandt Triple Sec
# ...

# %% [markdown]
# # 3. Converter a coluna de data para datetime
#
# # 4. Criar uma variável numérica baseada na data

# %% [markdown]
# # 5. Separar variáveis independentes (X) e dependente (y)

# %% [markdown]
# # 6. Dividir em treino e teste

# %% [markdown]
# # 7. Treinar o modelo

# %% [markdown]
# # 8. Fazer previsões

# %% [markdown]
# # 9. Avaliar o modelo

# %% [markdown]
# # 10. Visualizar os resultados

# %%
conn.close()
